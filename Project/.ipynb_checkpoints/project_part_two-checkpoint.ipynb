# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = (r"C:\Users\Steven\gwu-arl-data-pt-09-2020-u-c\02-Homework\04-Python-Pandas\03-Pandas-Project\Mini-Project-Part-1\Resources\2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df = pd.read_csv(file, encoding="ISO-8859-1", low_memory= False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
new_df = df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
new_df = new_df.replace({0.0: 'No', 1.0: 'Yes'})
new_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# 2            NaN            more than 1 million  ...
# 3            NaN            more than 1 million  ...
# 4            NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = new_df.loc[new_df['AttendedBootcamp'] == 'Yes']
attended_bootcamp.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampName            895
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
bootcamp_name = pd.DataFrame(df["BootcampName"].value_counts().rename_axis("BootcampName").reset_index(name = "Attendees"))
bootcamp_name
# Out:
#               BootcampName  Attendees
# 0         General Assembly         90
# 1          Flatiron School         54
# 2             Dev Bootcamp         48
# 3            The Iron Yard         40
# 4    Prime Digital Academy         30
# ..                     ...        ...
# 123      Ruby On The Beach          1
# 124    CodeMasters Academy          1
# 125      Founders & Coders          1
# 126      Data Science Dojo          1
# 127          Claim Academy          1
#
# [128 rows x 2 columns]

# %%
attended_bootcamp = new_df.loc[new_df['AttendedBootcamp'] == 'Yes']
attended_bootcamp = attended_bootcamp.loc[new_df['BootcampRecommend'] == 'Yes']

# Count how many attendees of each bootcamp would recommend the bootcamp
sum_recomended = pd.DataFrame(attended_bootcamp.groupby('BootcampName')["BootcampRecommend"].count())
sum_recomended.reset_index(inplace=True)
sum_recomended.columns=["BootcampName", "Recommenders"]

sum_recomended
# Out:
#             BootcampName  Recommenders
# 0             10x.org.il             3
# 1         4Geeks Academy             4
# 2               AcadGild             2
# 3    Academia de CÃ³digo             4
# 4                    Ada             8
# ..                   ...           ...
# 111              Wyncode             3
# 112  Zip Code Wilmington             1
# 113                codeU             1
# 114          devCodeCamp             4
# 115           tradecraft             1
#
# [116 rows x 2 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp
merged_df = pd.merge(sum_recomended, bootcamp_name, on="BootcampName")
merged_df
# Out:
#             BootcampName  Recommenders  Attendees
# 0             10x.org.il             3          5
# 1         4Geeks Academy             4          8
# 2               AcadGild             2          2
# 3    Academia de CÃ³digo             4          4
# 4                    Ada             8          9
# ..                   ...           ...        ...
# 111              Wyncode             3          6
# 112  Zip Code Wilmington             1          3
# 113                codeU             1          1
# 114          devCodeCamp             4          4
# 115           tradecraft             1          3
#
# [116 rows x 3 columns]

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
merged_df["% Recommend"] = round(merged_df["Recommenders"]/ merged_df["Attendees"]*100,2).map('{0:,.2f}%'.format)
merged_df = merged_df.sort_values(["% Recommend"], ascending=False)
merged_df.head()
# Out:
#                                           BootcampName  Recommenders  \
# 106                                             Turing            26
# 56   Free Code Camp is not a bootcamp - please scro...            14
# 62                                        Hack Reactor            27
# 54                                     Flatiron School            50
# 7                                          App Academy            20
#
#      Attendees % Recommend
# 106         27      96.30%
# 56          15      93.33%
# 62          29      93.10%
# 54          54      92.59%
# 7           22      90.91%

# %%
# Export to excel and remove index
merged_df.to_excel(r"C:\Users\Steven\Homework\pandas_challenge\Project\Project_Part_2.xlsx", index=False)
