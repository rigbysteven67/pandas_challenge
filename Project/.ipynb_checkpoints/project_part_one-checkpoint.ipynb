# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = (r"C:\Users\Steven\gwu-arl-data-pt-09-2020-u-c\02-Homework\04-Python-Pandas\03-Pandas-Project\Mini-Project-Part-2\Resources\2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas
df = pd.read_csv(file)
df.head()
# Out:
# C:\Users\Steven\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Inspect all columns
df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

new_df = df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million                NaN  United States of America
# 1  between 100,000 and 1 million                NaN  United States of America
# 2            more than 1 million                NaN  United States of America
# 3            more than 1 million                NaN  United States of America
# 4  between 100,000 and 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 0          0.0           30.0  32000.0                        NaN
# 1          NaN           30.0  15000.0    Front-End Web Developer
# 2          NaN           20.0  48000.0                        NaN
# 3          NaN           20.0  43000.0    Front-End Web Developer
# 4          NaN           25.0   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
new_df = new_df.replace({0.0: 'No', 1.0: 'Yes'})
new_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# 1  between 100,000 and 1 million               NaN  United States of America
# 2            more than 1 million               NaN  United States of America
# 3            more than 1 million               NaN  United States of America
# 4  between 100,000 and 1 million               NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#   HasChildren HoursLearning   Income            JobRoleInterest  \
# 0          No            30  32000.0                        NaN
# 1         NaN            30  15000.0    Front-End Web Developer
# 2         NaN            20  48000.0                        NaN
# 3         NaN            20  43000.0    Front-End Web Developer
# 4         NaN            25   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Calculate total number of respondents in survey
total_respondents = len(new_df['AttendedBootcamp'])
total_respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp = new_df.loc[new_df['AttendedBootcamp'] == 'Yes']
attended_bootcamp.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Calculate average age of attendees
average_age = attended_bootcamp["Age"].mean()

# Calculate how many people attended a bootcamp
people_attended = attended_bootcamp["AttendedBootcamp"].count()
# Calculate how many attendees hold degrees
hold_degree = attended_bootcamp["SchoolDegree"].count()
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
male = attended_bootcamp["Gender"].value_counts()['male']
female = attended_bootcamp["Gender"].value_counts()['female']
total_gender = attended_bootcamp["Gender"].count()
non_binary_gender = total_gender - male - female
# Calculate percentage of respondents who attended a bootcamp
percent_attended = (people_attended / total_respondents) * 100 
# Calculate percentage of respondents belonging to each gender
percent_male = (male / total_gender) * 100
percent_female = (female / total_gender) * 100
percent_non_binary_gender = (non_binary_gender / total_gender) * 100
# Calculate percentage of attendees with a school degree
degree_percent = (hold_degree / people_attended) * 100
# Calculate average post-bootcamp salary
avg_salary = attended_bootcamp["BootcampPostSalary"].mean()
avg_salary
# Out:
# 63740.50606060606

# %%
# Create a new table consolodating above calculations
bootcamp_new = pd.DataFrame({"Total Surveyed": [total_respondents],
                            "Total Bootcamp Attendees": [people_attended],
                            "% Attended Bootcamp": [percent_attended],
                            "Avg Age": [average_age],
                            "% Male":[percent_male],
                            "% Female": [percent_female],
                            "% Non Gender Specific": [percent_non_binary_gender],
                            "Graduated School": [degree_percent],
                            "Avg Post Bootcamp Salary": [avg_salary] })
bootcamp_new = bootcamp_new.round(2)
bootcamp_new
# Out:
#    Total Surveyed  Total Bootcamp Attendees  % Attended Bootcamp  Avg Age  \
# 0           15620                       953                  6.1    31.07
#
#    % Male  % Female  % Non Gender Specific  Graduated School  \
# 0   59.54     39.14                   1.32              87.3
#
#    Avg Post Bootcamp Salary
# 0                  63740.51

# %%
# Improve formatting before outputting spreadsheet
bootcamp_new["% Male"] = bootcamp_new["% Male"].map("{:.2f}%".format)
bootcamp_new["% Female"] = bootcamp_new["% Female"].map("{:.2f}%".format)
bootcamp_new["% Attended Bootcamp"] = bootcamp_new["% Attended Bootcamp"].map("{:.2f}%".format)
bootcamp_new["% Non Gender Specific"] = bootcamp_new["% Non Gender Specific"].map("{:.2f}%".format)
bootcamp_new["Graduated School"] = bootcamp_new["Graduated School"].map("{:.2f}%".format)
bootcamp_new["Avg Post Bootcamp Salary"] = bootcamp_new["Avg Post Bootcamp Salary"].map("${:.2f}".format)
bootcamp_new.dtypes
# Out:
# Total Surveyed                int64
# Total Bootcamp Attendees      int64
# % Attended Bootcamp          object
# Avg Age                     float64
# % Male                       object
# % Female                     object
# % Non Gender Specific        object
# Graduated School             object
# Avg Post Bootcamp Salary     object
# dtype: object

# %%
# Export to Excel
bootcamp_new.to_excel(r"C:\Users\Steven\Homework\pandas_challenge\Project\Project_Part_1.xlsx", index=False)
