# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
num_of_players = purchase_data['SN'].nunique()
num_of_players_df = pd.DataFrame([{'Number of Players':num_of_players}])
num_of_players_df
# Out:
#    Number of Players
# 0                576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
num_of_unique_items = len(purchase_data["Item ID"].unique())
total_of_purchases = purchase_data["Price"].sum()
num_of_purchases = len(purchase_data['Price'])
avg_purchase_price = total_of_purchases/num_of_purchases
purchasing_df = pd.DataFrame({"Number of Unique Items": [num_of_unique_items],
                             "Average Price": [avg_purchase_price],
                             'Number of Purchases': [num_of_purchases],
                             'Total Revenue': [total_of_purchases]})
purchasing_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %%
removed_dupes_df = purchase_data.drop_duplicates(subset=['SN'])
male_count = len(removed_dupes_df.loc[removed_dupes_df['Gender'] == 'Male', :])
male_percent = (male_count / num_of_players) * 100
female_count = len(removed_dupes_df.loc[removed_dupes_df['Gender'] == 'Female', :])
female_percent = (female_count / num_of_players) * 100
other_count = len(removed_dupes_df.loc[removed_dupes_df['Gender'] == 'Other / Non-Disclosed', :])
other_percent = (other_count / num_of_players) * 100
gender_demographics_df = pd.DataFrame({'Gender': ['Male', 'Female', 'Other / Non-Discosed'],
                      'Total Count': [male_count, female_count, other_count],
                      'Percentage of Players': [male_percent, female_percent, other_percent]})
gender_demographics_df
# Out:
#                  Gender  Total Count  Percentage of Players
# 0                  Male          484              84.027778
# 1                Female           81              14.062500
# 2  Other / Non-Discosed           11               1.909722

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
male_purchases = purchase_data.loc[purchase_data['Gender'] == 'Male', :]
male_purchases_count = len(male_purchases['Purchase ID'])
male_purchases_total = male_purchases['Price'].sum()
male_purchases_avg = male_purchases_total / male_purchases_count
male_purchases_avg_person = male_purchases_total / male_count

# %%
female_purchases = purchase_data.loc[purchase_data['Gender'] == 'Female', :]
female_purchases_count = len(female_purchases['Purchase ID'])
female_purchases_total = female_purchases['Price'].sum()
female_purchases_avg = female_purchases_total / female_purchases_count
female_purchases_avg_person = female_purchases_total / female_count

# %%
other_purchases = purchase_data.loc[purchase_data['Gender'] == 'Other / Non-Disclosed', :]
other_purchases_count = len(other_purchases['Purchase ID'])
other_purchases_total = other_purchases['Price'].sum()
other_purchases_avg = other_purchases_total / other_purchases_count
other_purchases_avg_person = other_purchases_total / other_count

# %%
purchasing_analysis_gender_df = pd.DataFrame({"Gender": ['Male', 'Female', 'Other / Non-Discolsed'],
                                            'Purchase Count': [male_purchases_count, female_purchases_count, other_purchases_count],
                                              'Average Purchase Price': [male_purchases_avg, female_purchases_avg, other_purchases_avg],
                                              'Total Purchase Value': [male_purchases_total, female_purchases_total, other_purchases_total],
                                              'Avg Total Purchase per Person': [male_purchases_avg_person, female_purchases_avg_person, other_purchases_avg_person]})
purchasing_analysis_gender_df
# Out:
#                   Gender  Purchase Count  Average Purchase Price  \
# 0                   Male             652                3.017853
# 1                 Female             113                3.203009
# 2  Other / Non-Discolsed              15                3.346000
#
#    Total Purchase Value  Avg Total Purchase per Person
# 0               1967.64                       4.065372
# 1                361.94                       4.468395
# 2                 50.19                       4.562727

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
purchase_data['Age_Group'] = pd.cut(removed_dupes_df.Age,
                              bins = [0,9,14,19,24,29,34,39,40], labels = ['<10,', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+'])
age_total_count = purchase_data['Age_Group'].value_counts()
age_df = pd.DataFrame({"Total Count": age_total_count})
percentages = (age_df['Total Count'] / num_of_players) *100
age_df['Percentage of Players'] = percentages
new_df = pd.DataFrame({"Total Count": age_total_count,
                      "Percentage of Players": percentages})
new_df.sort_index(inplace=True)
new_df
# Out:
#        Total Count  Percentage of Players
# <10,            17               2.951389
# 10-14           22               3.819444
# 15-19          107              18.576389
# 20-24          258              44.791667
# 25-29           77              13.368056
# 30-34           52               9.027778
# 35-39           31               5.381944
# 40+              5               0.868056

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data['Age Group'] = pd.cut(purchase_data.Age,
                              bins = [0,9,14,19,24,29,34,39,40], labels = ['<10,', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+'])
age_grouped_df = purchase_data.groupby(["Age Group"])
purchase_counts_grouped = age_grouped_df['Purchase ID'].count()
price_avg_grouped = age_grouped_df['Price'].mean()
total_purchase_grouped = age_grouped_df['Price'].sum()
avg_purchase_person_grouped = total_purchase_grouped / age_total_count
purchasing_age_grouped = pd.DataFrame({'Purchase Count': purchase_counts_grouped,
                                      'Average Purchase Price': price_avg_grouped,
                                      'Total Purchase Value': total_purchase_grouped,
                                      'Avg Total Purchase per Person': avg_purchase_person_grouped})
purchasing_age_grouped
# Out:
#        Purchase Count  Average Purchase Price  Total Purchase Value  \
# <10,               23                3.353478                 77.13
# 10-14              28                2.956429                 82.78
# 15-19             136                3.035956                412.89
# 20-24             365                3.052219               1114.06
# 25-29             101                2.900990                293.00
# 30-34              73                2.931507                214.00
# 35-39              41                3.601707                147.67
# 40+                 6                2.785000                 16.71
#
#        Avg Total Purchase per Person
# <10,                        4.537059
# 10-14                       3.762727
# 15-19                       3.858785
# 20-24                       4.318062
# 25-29                       3.805195
# 30-34                       4.115385
# 35-39                       4.763548
# 40+                         3.342000

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
name_grouped_df = purchase_data.groupby(['SN'])
purchase_counts_name = name_grouped_df['Purchase ID'].count()
price_avg_name = name_grouped_df['Price'].mean()
total_price_name = name_grouped_df['Price'].sum()
purchasing_name_grouped = pd.DataFrame({'Purchase Count': purchase_counts_name,
                                       'Average Purchase Price': price_avg_name,
                                       'Total Purchase Value': total_price_name})
sorted_df = purchasing_name_grouped.sort_values('Total Purchase Value', ascending = False)
sorted_df
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10
# ...                     ...                     ...                   ...
# Ililsasya43               1                1.020000                  1.02
# Irilis75                  1                1.020000                  1.02
# Aidai61                   1                1.010000                  1.01
# Chanirra79                1                1.010000                  1.01
# Alo38                     1                1.000000                  1.00
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_df = purchase_data.groupby(['Item ID', 'Item Name'])
purchase_count_popular = popular_df['Purchase ID'].count()
price_avg_popular = popular_df['Price'].mean()
total_price_popular = popular_df['Price'].sum()
new_popular_df = pd.DataFrame({'Purchase Count': purchase_count_popular,
                             'Item Price': price,
                             'Total Purchase Value': total_price_popular})
sorted_popular_df = new_popular_df.sort_values('Purchase Count', ascending = False)
sorted_popular_df
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# ...                                                              ...
# 42      The Decapitator                                            1
# 51      Endbringer                                                 1
# 118     Ghost Reaver, Longsword of Magic                           1
# 104     Gladiator's Glaive                                         1
# 91      Celeste                                                    1
#
#                                                       Item Price  \
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_df = sorted_popular_df.sort_values('Total Purchase Value', ascending = False)
most_profitable_df
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
# ...                                                              ...
# 28      Flux, Destroyer of Due Diligence                           2
# 126     Exiled Mithril Longsword                                   1
# 125     Whistling Mithril Warblade                                 2
# 104     Gladiator's Glaive                                         1
# 42      The Decapitator                                            1
#
#                                                       Item Price  \
# Item ID Item Name
# ...
